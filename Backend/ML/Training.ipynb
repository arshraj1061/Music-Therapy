# %% [markdown]
# <a href="https://colab.research.google.com/github/arshraj1061/Music-Therapy/blob/main/Backend/ML/Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import ML required packages
import numpy as np
import pandas as pd
import keras
from keras.utils import to_categorical
#Import Libraries before model creation
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,BatchNormalization
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.losses import categorical_crossentropy
from keras.optimizers import Adam
from keras.regularizers import l2
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix,classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import xml.etree.ElementTree as ET
# %matplotlib inline

#Load and Read the dataset
emotion_data = pd.read_csv('/content/drive/MyDrive/fer2013.csv')
print('Dataset loaded successfully')

emotion_data.head()

emotion_data.tail()

emotion_data.Usage.value_counts()

# Pull out dataset in different categories
data_train = emotion_data[emotion_data['Usage'] == 'Training'].copy()
data_val = emotion_data[emotion_data['Usage'] == 'PublicTest'].copy()
data_test = emotion_data[emotion_data['Usage'] == 'PrivateTest'].copy()

# Shuffle the training data
data_train = data_train.sample(frac=1, random_state=42)

# Get the first 'desired_training_size' samples for training
data_train = data_train.head(35000)

# Print the updated dataset shapes
print('Train shape: {}\nValidation shape: {}\nTest shape: {}'.format(data_train.shape, data_val.shape, data_test.shape))


#Initialize Parameters
num_classes = 7
epochs = 100
batch_size = 64
num_features = 32
width, height = 48,48

emotion_data.shape

emotion_data.describe()

#checking for missing values
emotion_data.isna().sum()

sns.set_theme(style='darkgrid', palette='deep', font='sans-serif', font_scale=1)
sns.histplot(data= emotion_data,kde = True)

#Data Preprocessing
#Perform CRNO (CRNO stands for Convert,Reshape, Normalize, one-hot-encoding)
def CRNO(df,dataName):
    df['pixels'] = df['pixels'].apply(lambda pixel_sequence: [int(pixel) for pixel in pixel_sequence.split()])
    data_X = np.array(df['pixels'].tolist(),dtype='float32').reshape(-1,width,height,1)/255.0
    data_Y = to_categorical(df['emotion'],num_classes)
    print(dataName, "_X shape: {}, ", dataName, "_Y shape: {}".format(data_X.shape, data_Y.shape))
    return data_X,data_Y

train_X,train_Y = CRNO(data_train,'train')
val_X,val_Y = CRNO(data_val,'validation')
test_X,test_Y = CRNO(data_test,'test')

#Build the model
model = Sequential()
#Module1 conv<<conv<<batchnorm<<relu<<maxpooling<<dropout
model.add(Conv2D(2*num_features,kernel_size=(3,3),padding='same',data_format='channels_last',input_shape=(width, height, 1)))
model.add(Conv2D(2*num_features,kernel_size=(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D())
model.add(Dropout(rate=0.2))
#Module2 conv<<conv<<batchnorm<<relu<<maxpool<<dropout
model.add(Conv2D(2*2*num_features,kernel_size=(3,3),padding='same'))
model.add(Conv2D(2*2*num_features,kernel_size=(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D())
model.add(Dropout(rate=0.2))
#Module3 conv<<conv<<batchnorm<<relu<<maxpool<<dropout
model.add(Conv2D(2*2*2*num_features,kernel_size=(1,1),padding='same'))
model.add(Conv2D(2*2*2*num_features,kernel_size=(1,1),strides=(2,2)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D())
model.add(Dropout(rate=0.2))
#Module4 fc<<batchnorm<<fc<<batchnorm<<dropout<<softmax
model.add(Flatten())
model.add(Dense(units=128))
model.add(BatchNormalization())
model.add(Dense(units=128))
model.add(BatchNormalization())
model.add(Dropout(rate=0.2))
model.add(Dense(num_classes,activation='softmax'))

model.compile(loss='categorical_crossentropy',optimizer=Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999),metrics=['accuracy'])
model.summary()

#Training the model
# es = EarlyStopping(monitor='val_loss', patience = 10, mode = 'min', restore_best_weights=True)

history = model.fit(train_X,train_Y,batch_size=64,epochs=150,verbose=1,validation_split=1,validation_data=(val_X,val_Y),shuffle=True)
# Out:
# Dataset loaded successfully
# Train shape: (28709, 3)
# Validation shape: (3589, 3)
# Test shape: (3589, 3)
# train _X shape: {},  train _Y shape: (28709, 48, 48, 1)
# validation _X shape: {},  validation _Y shape: (3589, 48, 48, 1)
# test _X shape: {},  test _Y shape: (3589, 48, 48, 1)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 48, 48, 64)        640
#
#  conv2d_7 (Conv2D)           (None, 48, 48, 64)        36928
#
#  batch_normalization_5 (Batc  (None, 48, 48, 64)       256
#  hNormalization)
#
#  activation_3 (Activation)   (None, 48, 48, 64)        0
#
#  max_pooling2d_3 (MaxPooling  (None, 24, 24, 64)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 24, 24, 64)        0
#
#  conv2d_8 (Conv2D)           (None, 24, 24, 128)       73856
#
#  conv2d_9 (Conv2D)           (None, 24, 24, 128)       147584
#
#  batch_normalization_6 (Batc  (None, 24, 24, 128)      512
#  hNormalization)
#
#  activation_4 (Activation)   (None, 24, 24, 128)       0
#
#  max_pooling2d_4 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  dropout_5 (Dropout)         (None, 12, 12, 128)       0
#
#  conv2d_10 (Conv2D)          (None, 12, 12, 256)       33024
#
#  conv2d_11 (Conv2D)          (None, 6, 6, 256)         65792
#
#  batch_normalization_7 (Batc  (None, 6, 6, 256)        1024
#  hNormalization)
#
#  activation_5 (Activation)   (None, 6, 6, 256)         0
#
#  max_pooling2d_5 (MaxPooling  (None, 3, 3, 256)        0
#  2D)
#
#  dropout_6 (Dropout)         (None, 3, 3, 256)         0
#
#  flatten_1 (Flatten)         (None, 2304)              0
#
#  dense_3 (Dense)             (None, 128)               295040
#
#  batch_normalization_8 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  batch_normalization_9 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 673,095
# Trainable params: 671,687
# Non-trainable params: 1,408
# _________________________________________________________________
# Epoch 1/150
# 449/449 [==============================] - 17s 36ms/step - loss: 1.8085 - accuracy: 0.3153 - val_loss: 1.7215 - val_accuracy: 0.3352
# Epoch 2/150
# 449/449 [==============================] - 16s 35ms/step - loss: 1.4885 - accuracy: 0.4357 - val_loss: 1.4741 - val_accuracy: 0.4517
# Epoch 3/150
# 449/449 [==============================] - 16s 35ms/step - loss: 1.3818 - accuracy: 0.4738 - val_loss: 1.3342 - val_accuracy: 0.5001
# Epoch 4/150
# 449/449 [==============================] - 16s 35ms/step - loss: 1.3238 - accuracy: 0.4967 - val_loss: 1.3671 - val_accuracy: 0.4773
# Epoch 5/150
# 449/449 [==============================] - 16s 35ms/step - loss: 1.2813 - accuracy: 0.5128 - val_loss: 1.2776 - val_accuracy: 0.5199
# Epoch 6/150
# 449/449 [==============================] - 16s 35ms/step - loss: 1.2529 - accuracy: 0.5277 - val_loss: 1.2679 - val_accuracy: 0.5258
# Epoch 7/150
# 449/449 [==============================] - 16s 35ms/step - loss: 1.2309 - accuracy: 0.5378 - val_loss: 1.2985 - val_accuracy: 0.5071
# Epoch 8/150
# 449/449 [==============================] - 16s 35ms/step - loss: 1.2069 - accuracy: 0.5460 - val_loss: 1.2334 - val_accuracy: 0.5352
# Epoch 9/150
# 449/449 [==============================] - 16s 35ms/step - loss: 1.1897 - accuracy: 0.5517 - val_loss: 1.2905 - val_accuracy: 0.5146
# Epoch 10/150
# 449/449 [==============================] - 15s 34ms/step - loss: 1.1750 - accuracy: 0.5576 - val_loss: 1.4413 - val_accuracy: 0.4500
# Epoch 11/150
# 449/449 [==============================] - 16s 35ms/step - loss: 1.1573 - accuracy: 0.5640 - val_loss: 1.1942 - val_accuracy: 0.5508
# Epoch 12/150
# 449/449 [==============================] - 16s 35ms/step - loss: 1.1410 - accuracy: 0.5706 - val_loss: 1.2107 - val_accuracy: 0.5450
# Epoch 13/150
# 449/449 [==============================] - 16s 35ms/step - loss: 1.1244 - accuracy: 0.5757 - val_loss: 1.2223 - val_accuracy: 0.5456
# Epoch 14/150
# 449/449 [==============================] - 16s 35ms/step - loss: 1.1068 - accuracy: 0.5847 - val_loss: 1.2322 - val_accuracy: 0.5450
# Epoch 15/150
# 449/449 [==============================] - 15s 34ms/step - loss: 1.0997 - accuracy: 0.5859 - val_loss: 1.2190 - val_accuracy: 0.5467
# Epoch 16/150
# 449/449 [==============================] - 16s 35ms/step - loss: 1.0894 - accuracy: 0.5903 - val_loss: 1.1896 - val_accuracy: 0.5500
# Epoch 17/150
# 449/449 [==============================] - 16s 35ms/step - loss: 1.0718 - accuracy: 0.5989 - val_loss: 1.1970 - val_accuracy: 0.5417
# Epoch 18/150
# 449/449 [==============================] - 16s 35ms/step - loss: 1.0608 - accuracy: 0.5991 - val_loss: 1.1935 - val_accuracy: 0.5584
# Epoch 19/150
# 449/449 [==============================] - 16s 35ms/step - loss: 1.0462 - accuracy: 0.6071 - val_loss: 1.2660 - val_accuracy: 0.5311
# Epoch 20/150
# 449/449 [==============================] - 16s 35ms/step - loss: 1.0408 - accuracy: 0.6085 - val_loss: 1.1571 - val_accuracy: 0.5637
# Epoch 21/150
# 449/449 [==============================] - 16s 35ms/step - loss: 1.0292 - accuracy: 0.6156 - val_loss: 1.1634 - val_accuracy: 0.5715
# Epoch 22/150
# 449/449 [==============================] - 15s 34ms/step - loss: 1.0163 - accuracy: 0.6225 - val_loss: 1.1542 - val_accuracy: 0.5709
# Epoch 23/150
# 449/449 [==============================] - 16s 35ms/step - loss: 1.0050 - accuracy: 0.6243 - val_loss: 1.1465 - val_accuracy: 0.5717
# Epoch 24/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.9984 - accuracy: 0.6253 - val_loss: 1.1337 - val_accuracy: 0.5756
# Epoch 25/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.9868 - accuracy: 0.6310 - val_loss: 1.1589 - val_accuracy: 0.5609
# Epoch 26/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.9741 - accuracy: 0.6404 - val_loss: 1.1385 - val_accuracy: 0.5832
# Epoch 27/150
# 449/449 [==============================] - 15s 35ms/step - loss: 0.9720 - accuracy: 0.6371 - val_loss: 1.1972 - val_accuracy: 0.5531
# Epoch 28/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.9604 - accuracy: 0.6456 - val_loss: 1.2325 - val_accuracy: 0.5522
# Epoch 29/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.9528 - accuracy: 0.6437 - val_loss: 1.1816 - val_accuracy: 0.5600
# Epoch 30/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.9401 - accuracy: 0.6487 - val_loss: 1.1515 - val_accuracy: 0.5798
# Epoch 31/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.9367 - accuracy: 0.6520 - val_loss: 1.1715 - val_accuracy: 0.5659
# Epoch 32/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.9344 - accuracy: 0.6505 - val_loss: 1.1774 - val_accuracy: 0.5656
# Epoch 33/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.9176 - accuracy: 0.6575 - val_loss: 1.1544 - val_accuracy: 0.5740
# Epoch 34/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.9087 - accuracy: 0.6603 - val_loss: 1.1805 - val_accuracy: 0.5637
# Epoch 35/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.9066 - accuracy: 0.6606 - val_loss: 1.1556 - val_accuracy: 0.5815
# Epoch 36/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.9060 - accuracy: 0.6619 - val_loss: 1.1819 - val_accuracy: 0.5717
# Epoch 37/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.9026 - accuracy: 0.6626 - val_loss: 1.1403 - val_accuracy: 0.5773
# Epoch 38/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.8894 - accuracy: 0.6664 - val_loss: 1.1728 - val_accuracy: 0.5575
# Epoch 39/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.8833 - accuracy: 0.6701 - val_loss: 1.1521 - val_accuracy: 0.5676
# Epoch 40/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.8784 - accuracy: 0.6741 - val_loss: 1.1841 - val_accuracy: 0.5662
# Epoch 41/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.8655 - accuracy: 0.6778 - val_loss: 1.1586 - val_accuracy: 0.5795
# Epoch 42/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.8640 - accuracy: 0.6767 - val_loss: 1.1832 - val_accuracy: 0.5798
# Epoch 43/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.8637 - accuracy: 0.6775 - val_loss: 1.1461 - val_accuracy: 0.5823
# Epoch 44/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.8560 - accuracy: 0.6824 - val_loss: 1.1513 - val_accuracy: 0.5807
# Epoch 45/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.8500 - accuracy: 0.6824 - val_loss: 1.1589 - val_accuracy: 0.5815
# Epoch 46/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.8421 - accuracy: 0.6826 - val_loss: 1.2026 - val_accuracy: 0.5631
# Epoch 47/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.8437 - accuracy: 0.6845 - val_loss: 1.1690 - val_accuracy: 0.5701
# Epoch 48/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.8390 - accuracy: 0.6869 - val_loss: 1.1355 - val_accuracy: 0.5829
# Epoch 49/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.8316 - accuracy: 0.6906 - val_loss: 1.1564 - val_accuracy: 0.5770
# Epoch 50/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.8300 - accuracy: 0.6917 - val_loss: 1.1501 - val_accuracy: 0.5809
# Epoch 51/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.8193 - accuracy: 0.6944 - val_loss: 1.1850 - val_accuracy: 0.5729
# Epoch 52/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.8232 - accuracy: 0.6953 - val_loss: 1.1810 - val_accuracy: 0.5821
# Epoch 53/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.8099 - accuracy: 0.6973 - val_loss: 1.1842 - val_accuracy: 0.5765
# Epoch 54/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.8080 - accuracy: 0.7011 - val_loss: 1.1882 - val_accuracy: 0.5745
# Epoch 55/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.8076 - accuracy: 0.6961 - val_loss: 1.1583 - val_accuracy: 0.5807
# Epoch 56/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.7989 - accuracy: 0.7025 - val_loss: 1.1670 - val_accuracy: 0.5770
# Epoch 57/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.8019 - accuracy: 0.7015 - val_loss: 1.1895 - val_accuracy: 0.5734
# Epoch 58/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.7957 - accuracy: 0.7044 - val_loss: 1.1628 - val_accuracy: 0.5804
# Epoch 59/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.7932 - accuracy: 0.7057 - val_loss: 1.2054 - val_accuracy: 0.5765
# Epoch 60/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.7925 - accuracy: 0.7046 - val_loss: 1.2146 - val_accuracy: 0.5665
# Epoch 61/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.7843 - accuracy: 0.7047 - val_loss: 1.1754 - val_accuracy: 0.5818
# Epoch 62/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.7824 - accuracy: 0.7097 - val_loss: 1.1772 - val_accuracy: 0.5823
# Epoch 63/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.7773 - accuracy: 0.7082 - val_loss: 1.1399 - val_accuracy: 0.5865
# Epoch 64/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.7823 - accuracy: 0.7063 - val_loss: 1.1591 - val_accuracy: 0.5857
# Epoch 65/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.7757 - accuracy: 0.7123 - val_loss: 1.1787 - val_accuracy: 0.5754
# Epoch 66/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.7639 - accuracy: 0.7152 - val_loss: 1.1650 - val_accuracy: 0.5818
# Epoch 67/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.7619 - accuracy: 0.7160 - val_loss: 1.1916 - val_accuracy: 0.5840
# Epoch 68/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.7665 - accuracy: 0.7153 - val_loss: 1.1628 - val_accuracy: 0.5854
# Epoch 69/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.7571 - accuracy: 0.7173 - val_loss: 1.1747 - val_accuracy: 0.5885
# Epoch 70/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.7570 - accuracy: 0.7227 - val_loss: 1.1795 - val_accuracy: 0.5876
# Epoch 71/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.7517 - accuracy: 0.7204 - val_loss: 1.1910 - val_accuracy: 0.5720
# Epoch 72/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.7493 - accuracy: 0.7213 - val_loss: 1.2280 - val_accuracy: 0.5768
# Epoch 73/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.7536 - accuracy: 0.7165 - val_loss: 1.1853 - val_accuracy: 0.5874
# Epoch 74/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.7424 - accuracy: 0.7223 - val_loss: 1.1939 - val_accuracy: 0.5793
# Epoch 75/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.7377 - accuracy: 0.7265 - val_loss: 1.2097 - val_accuracy: 0.5868
# Epoch 76/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.7354 - accuracy: 0.7278 - val_loss: 1.1952 - val_accuracy: 0.5837
# Epoch 77/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.7424 - accuracy: 0.7271 - val_loss: 1.1768 - val_accuracy: 0.5857
# Epoch 78/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.7320 - accuracy: 0.7259 - val_loss: 1.2061 - val_accuracy: 0.5706
# Epoch 79/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.7270 - accuracy: 0.7311 - val_loss: 1.1873 - val_accuracy: 0.5899
# Epoch 80/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.7274 - accuracy: 0.7306 - val_loss: 1.2064 - val_accuracy: 0.5793
# Epoch 81/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.7248 - accuracy: 0.7309 - val_loss: 1.2266 - val_accuracy: 0.5851
# Epoch 82/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.7231 - accuracy: 0.7326 - val_loss: 1.2324 - val_accuracy: 0.5589
# Epoch 83/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.7221 - accuracy: 0.7321 - val_loss: 1.2711 - val_accuracy: 0.5634
# Epoch 84/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.7140 - accuracy: 0.7321 - val_loss: 1.2063 - val_accuracy: 0.5868
# Epoch 85/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.7152 - accuracy: 0.7319 - val_loss: 1.1795 - val_accuracy: 0.5865
# Epoch 86/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.7117 - accuracy: 0.7361 - val_loss: 1.1887 - val_accuracy: 0.5762
# Epoch 87/150
# 449/449 [==============================] - 15s 35ms/step - loss: 0.7085 - accuracy: 0.7360 - val_loss: 1.2116 - val_accuracy: 0.5729
# Epoch 88/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.7035 - accuracy: 0.7368 - val_loss: 1.2815 - val_accuracy: 0.5508
# Epoch 89/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.7006 - accuracy: 0.7367 - val_loss: 1.2235 - val_accuracy: 0.5821
# Epoch 90/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.7031 - accuracy: 0.7387 - val_loss: 1.1896 - val_accuracy: 0.5868
# Epoch 91/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6961 - accuracy: 0.7419 - val_loss: 1.1974 - val_accuracy: 0.5784
# Epoch 92/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6986 - accuracy: 0.7392 - val_loss: 1.1941 - val_accuracy: 0.5896
# Epoch 93/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6963 - accuracy: 0.7405 - val_loss: 1.1975 - val_accuracy: 0.5773
# Epoch 94/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6992 - accuracy: 0.7404 - val_loss: 1.2043 - val_accuracy: 0.5876
# Epoch 95/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6904 - accuracy: 0.7453 - val_loss: 1.2055 - val_accuracy: 0.5860
# Epoch 96/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6861 - accuracy: 0.7443 - val_loss: 1.1958 - val_accuracy: 0.5843
# Epoch 97/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.6938 - accuracy: 0.7422 - val_loss: 1.2084 - val_accuracy: 0.5798
# Epoch 98/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.6858 - accuracy: 0.7437 - val_loss: 1.2301 - val_accuracy: 0.5795
# Epoch 99/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6871 - accuracy: 0.7440 - val_loss: 1.1871 - val_accuracy: 0.5904
# Epoch 100/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6829 - accuracy: 0.7481 - val_loss: 1.2386 - val_accuracy: 0.5782
# Epoch 101/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6798 - accuracy: 0.7480 - val_loss: 1.2171 - val_accuracy: 0.5762
# Epoch 102/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6751 - accuracy: 0.7492 - val_loss: 1.2425 - val_accuracy: 0.5751
# Epoch 103/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6804 - accuracy: 0.7512 - val_loss: 1.2074 - val_accuracy: 0.5815
# Epoch 104/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6732 - accuracy: 0.7492 - val_loss: 1.2343 - val_accuracy: 0.5879
# Epoch 105/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6690 - accuracy: 0.7542 - val_loss: 1.2036 - val_accuracy: 0.5882
# Epoch 106/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.6700 - accuracy: 0.7492 - val_loss: 1.2451 - val_accuracy: 0.5754
# Epoch 107/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.6726 - accuracy: 0.7505 - val_loss: 1.2247 - val_accuracy: 0.5795
# Epoch 108/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.6597 - accuracy: 0.7540 - val_loss: 1.2291 - val_accuracy: 0.5826
# Epoch 109/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6673 - accuracy: 0.7520 - val_loss: 1.2379 - val_accuracy: 0.5712
# Epoch 110/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6644 - accuracy: 0.7558 - val_loss: 1.2175 - val_accuracy: 0.5823
# Epoch 111/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.6646 - accuracy: 0.7529 - val_loss: 1.2580 - val_accuracy: 0.5784
# Epoch 112/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.6631 - accuracy: 0.7539 - val_loss: 1.2334 - val_accuracy: 0.5784
# Epoch 113/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.6600 - accuracy: 0.7550 - val_loss: 1.2501 - val_accuracy: 0.5745
# Epoch 114/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6563 - accuracy: 0.7561 - val_loss: 1.2529 - val_accuracy: 0.5731
# Epoch 115/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6512 - accuracy: 0.7597 - val_loss: 1.2451 - val_accuracy: 0.5701
# Epoch 116/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6552 - accuracy: 0.7540 - val_loss: 1.2306 - val_accuracy: 0.5834
# Epoch 117/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6526 - accuracy: 0.7583 - val_loss: 1.2273 - val_accuracy: 0.5784
# Epoch 118/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.6538 - accuracy: 0.7554 - val_loss: 1.2301 - val_accuracy: 0.5790
# Epoch 119/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6513 - accuracy: 0.7594 - val_loss: 1.2236 - val_accuracy: 0.5865
# Epoch 120/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6477 - accuracy: 0.7642 - val_loss: 1.2312 - val_accuracy: 0.5812
# Epoch 121/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.6409 - accuracy: 0.7626 - val_loss: 1.2557 - val_accuracy: 0.5731
# Epoch 122/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6425 - accuracy: 0.7631 - val_loss: 1.2177 - val_accuracy: 0.5795
# Epoch 123/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6445 - accuracy: 0.7601 - val_loss: 1.2347 - val_accuracy: 0.5754
# Epoch 124/150
# 449/449 [==============================] - 15s 35ms/step - loss: 0.6458 - accuracy: 0.7597 - val_loss: 1.2528 - val_accuracy: 0.5704
# Epoch 125/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6366 - accuracy: 0.7639 - val_loss: 1.2523 - val_accuracy: 0.5790
# Epoch 126/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.6410 - accuracy: 0.7633 - val_loss: 1.2270 - val_accuracy: 0.5712
# Epoch 127/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6390 - accuracy: 0.7650 - val_loss: 1.2850 - val_accuracy: 0.5743
# Epoch 128/150
# 449/449 [==============================] - 16s 36ms/step - loss: 0.6229 - accuracy: 0.7695 - val_loss: 1.2315 - val_accuracy: 0.5826
# Epoch 129/150
# 449/449 [==============================] - 17s 37ms/step - loss: 0.6304 - accuracy: 0.7645 - val_loss: 1.2613 - val_accuracy: 0.5823
# Epoch 130/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6314 - accuracy: 0.7679 - val_loss: 1.2407 - val_accuracy: 0.5837
# Epoch 131/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6389 - accuracy: 0.7616 - val_loss: 1.2386 - val_accuracy: 0.5851
# Epoch 132/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.6337 - accuracy: 0.7655 - val_loss: 1.2474 - val_accuracy: 0.5879
# Epoch 133/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.6297 - accuracy: 0.7639 - val_loss: 1.2093 - val_accuracy: 0.5879
# Epoch 134/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.6264 - accuracy: 0.7669 - val_loss: 1.2904 - val_accuracy: 0.5687
# Epoch 135/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6188 - accuracy: 0.7715 - val_loss: 1.2591 - val_accuracy: 0.5681
# Epoch 136/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6278 - accuracy: 0.7663 - val_loss: 1.2714 - val_accuracy: 0.5779
# Epoch 137/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6310 - accuracy: 0.7682 - val_loss: 1.2507 - val_accuracy: 0.5762
# Epoch 138/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6232 - accuracy: 0.7676 - val_loss: 1.2511 - val_accuracy: 0.5843
# Epoch 139/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6211 - accuracy: 0.7702 - val_loss: 1.2600 - val_accuracy: 0.5851
# Epoch 140/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6057 - accuracy: 0.7762 - val_loss: 1.2676 - val_accuracy: 0.5804
# Epoch 141/150
# 449/449 [==============================] - 15s 34ms/step - loss: 0.6150 - accuracy: 0.7742 - val_loss: 1.2610 - val_accuracy: 0.5826
# Epoch 142/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6187 - accuracy: 0.7736 - val_loss: 1.2361 - val_accuracy: 0.5809
# Epoch 143/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6157 - accuracy: 0.7728 - val_loss: 1.2529 - val_accuracy: 0.5821
# Epoch 144/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6156 - accuracy: 0.7735 - val_loss: 1.2249 - val_accuracy: 0.5899
# Epoch 145/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6117 - accuracy: 0.7758 - val_loss: 1.2910 - val_accuracy: 0.5784
# Epoch 146/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6201 - accuracy: 0.7711 - val_loss: 1.2496 - val_accuracy: 0.5815
# Epoch 147/150
# 449/449 [==============================] - 15s 35ms/step - loss: 0.6046 - accuracy: 0.7783 - val_loss: 1.2414 - val_accuracy: 0.5876
# Epoch 148/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6099 - accuracy: 0.7734 - val_loss: 1.2489 - val_accuracy: 0.5762
# Epoch 149/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6013 - accuracy: 0.7762 - val_loss: 1.2544 - val_accuracy: 0.5851
# Epoch 150/150
# 449/449 [==============================] - 16s 35ms/step - loss: 0.6050 - accuracy: 0.7769 - val_loss: 1.2478 - val_accuracy: 0.5876

# %%
loss_and_metrics = model.evaluate(test_X,test_Y)
print(loss_and_metrics)

#Evaluate the test performance
test_true = np.argmax(test_Y, axis=1)
test_pred = np.argmax(model.predict(test_X), axis=1)
print("CNN Model Accuracy on test set: {:.4f}".format(accuracy_score(test_true, test_pred)))

import json
model_json = model.to_json()
with open("model.json", "w") as json_file:
  json_file.write(model_json)
  model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# 113/113 [==============================] - 1s 6ms/step - loss: 1.2187 - accuracy: 0.5918
# [1.2187232971191406, 0.5918083190917969]
# 113/113 [==============================] - 1s 4ms/step
# CNN Model Accuracy on test set: 0.5918
# Saved model to disk
